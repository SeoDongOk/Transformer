# %%
# %pip install pandas
# %pip install ko-sentence-transformers
# Out:
# Collecting ko-sentence-transformers
#   Downloading ko_sentence_transformers-0.3.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Collecting sentence-transformers (from ko-sentence-transformers)
#   Downloading sentence_transformers-3.0.1-py3-none-any.whl.metadata (10 kB)
# Collecting transformers<5.0.0,>=4.34.0 (from sentence-transformers->ko-sentence-transformers)
#   Downloading transformers-4.44.0-py3-none-any.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 4.4 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /Users/seodong-og/anaconda3/envs/torch_train/lib/python3.11/site-packages (from sentence-transformers->ko-sentence-transformers) (4.66.5)
# Requirement already satisfied: torch>=1.11.0 in /Users/seodong-og/anaconda3/envs/torch_train/lib/python3.11/site-packages (from sentence-transformers->ko-sentence-transformers) (2.0.0)
# Requirement already satisfied: numpy in /Users/seodong-og/anaconda3/envs/torch_train/lib/python3.11/site-packages (from sentence-transformers->ko-sentence-transformers) (1.26.4)
# Collecting scikit-learn (from sentence-transformers->ko-sentence-transformers)
#   Downloading scikit_learn-1.5.1-cp311-cp311-macosx_12_0_arm64.whl.metadata (12 kB)
# Collecting scipy (from sentence-transformers->ko-sentence-transformers)
#   Downloading scipy-1.14.0-cp311-cp311-macosx_14_0_arm64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 8.8 MB/s eta 0:00:00
# Collecting huggingface-hub>=0.15.1 (from sentence-transformers->ko-sentence-transformers)
#   Downloading huggingface_hub-0.24.5-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: Pillow in /Users/seodong-og/anaconda3/envs/torch_train/lib/python3.11/site-packages (from sentence-transformers->ko-sentence-transformers) (10.4.0)
# Requirement already satisfied: filelock in /Users/seodong-og/anaconda3/envs/torch_train/lib/python3.11/site-packages (from huggingface-hub>=0.15.1->sentence-transformers->ko-sentence-transformers) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/seodong-og/anaconda3/envs/torch_train/lib/python3.11/site-packages (from huggingface-hub>=0.15.1->sentence-transformers->ko-sentence-transformers) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in /Users/seodong-og/anaconda3/envs/torch_train/lib/python3.11/site-packages (from huggingface-hub>=0.15.1->sentence-transformers->ko-sentence-transformers) (24.1)
# Collecting pyyaml>=5.1 (from huggingface-hub>=0.15.1->sentence-transformers->ko-sentence-transformers)
#   Downloading PyYAML-6.0.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.1 kB)
# Requirement already satisfied: requests in /Users/seodong-og/anaconda3/envs/torch_train/lib/python3.11/site-packages (from huggingface-hub>=0.15.1->sentence-transformers->ko-sentence-transformers) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/seodong-og/anaconda3/envs/torch_train/lib/python3.11/site-packages (from huggingface-hub>=0.15.1->sentence-transformers->ko-sentence-transformers) (4.12.2)
# Requirement already satisfied: sympy in /Users/seodong-og/anaconda3/envs/torch_train/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers->ko-sentence-transformers) (1.13.1)
# Requirement already satisfied: networkx in /Users/seodong-og/anaconda3/envs/torch_train/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers->ko-sentence-transformers) (3.3)
# Requirement already satisfied: jinja2 in /Users/seodong-og/anaconda3/envs/torch_train/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers->ko-sentence-transformers) (3.1.4)
# Collecting regex!=2019.12.17 (from transformers<5.0.0,>=4.34.0->sentence-transformers->ko-sentence-transformers)
#   Using cached regex-2024.7.24-cp311-cp311-macosx_11_0_arm64.whl.metadata (40 kB)
# Collecting safetensors>=0.4.1 (from transformers<5.0.0,>=4.34.0->sentence-transformers->ko-sentence-transformers)
#   Downloading safetensors-0.4.4-cp311-cp311-macosx_11_0_arm64.whl.metadata (3.8 kB)
# Collecting tokenizers<0.20,>=0.19 (from transformers<5.0.0,>=4.34.0->sentence-transformers->ko-sentence-transformers)
#   Downloading tokenizers-0.19.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.7 kB)
# Collecting joblib>=1.2.0 (from scikit-learn->sentence-transformers->ko-sentence-transformers)
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn->sentence-transformers->ko-sentence-transformers)
#   Using cached threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/seodong-og/anaconda3/envs/torch_train/lib/python3.11/site-packages (from jinja2->torch>=1.11.0->sentence-transformers->ko-sentence-transformers) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/seodong-og/anaconda3/envs/torch_train/lib/python3.11/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers->ko-sentence-transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/seodong-og/anaconda3/envs/torch_train/lib/python3.11/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers->ko-sentence-transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/seodong-og/anaconda3/envs/torch_train/lib/python3.11/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers->ko-sentence-transformers) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/seodong-og/anaconda3/envs/torch_train/lib/python3.11/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers->ko-sentence-transformers) (2024.7.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/seodong-og/anaconda3/envs/torch_train/lib/python3.11/site-packages (from sympy->torch>=1.11.0->sentence-transformers->ko-sentence-transformers) (1.3.0)
# Downloading sentence_transformers-3.0.1-py3-none-any.whl (227 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 14.5 MB/s eta 0:00:00
# Downloading huggingface_hub-0.24.5-py3-none-any.whl (417 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.5/417.5 kB 28.6 MB/s eta 0:00:00
# Downloading transformers-4.44.0-py3-none-any.whl (9.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 45.1 MB/s eta 0:00:0000:0100:01
# Downloading scikit_learn-1.5.1-cp311-cp311-macosx_12_0_arm64.whl (11.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 27.7 MB/s eta 0:00:0000:0100:01
# Downloading scipy-1.14.0-cp311-cp311-macosx_14_0_arm64.whl (23.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.1/23.1 MB 47.8 MB/s eta 0:00:0000:0100:01
# Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Downloading PyYAML-6.0.2-cp311-cp311-macosx_11_0_arm64.whl (172 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.0/172.0 kB 11.6 MB/s eta 0:00:00
# Using cached regex-2024.7.24-cp311-cp311-macosx_11_0_arm64.whl (278 kB)
# Downloading safetensors-0.4.4-cp311-cp311-macosx_11_0_arm64.whl (381 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 381.5/381.5 kB 12.5 MB/s eta 0:00:00
# Using cached threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Downloading tokenizers-0.19.1-cp311-cp311-macosx_11_0_arm64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 38.6 MB/s eta 0:00:00a 0:00:01
# Building wheels for collected packages: ko-sentence-transformers
#   Building wheel for ko-sentence-transformers (setup.py) ... done
#   Created wheel for ko-sentence-transformers: filename=ko_sentence_transformers-0.3-py3-none-any.whl size=9682 sha256=6d114fa6d7aa0b3b9cad3f74d05a21a264a63f1f2bf44909b3e905e81f0cc871
#   Stored in directory: /Users/seodong-og/Library/Caches/pip/wheels/c4/6e/08/8475976a25db7945811c28e1ea5526e10ecdf0568176610716
# Successfully built ko-sentence-transformers
# Installing collected packages: threadpoolctl, scipy, safetensors, regex, pyyaml, joblib, scikit-learn, huggingface-hub, tokenizers, transformers, sentence-transformers, ko-sentence-transformers
# Successfully installed huggingface-hub-0.24.5 joblib-1.4.2 ko-sentence-transformers-0.3 pyyaml-6.0.2 regex-2024.7.24 safetensors-0.4.4 scikit-learn-1.5.1 scipy-1.14.0 sentence-transformers-3.0.1 threadpoolctl-3.5.0 tokenizers-0.19.1 transformers-4.44.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df = pd.read_csv("naver_shopping.txt",sep='\t', on_bad_lines='skip')

# %%
df
# Out:
#         5                                            배공빠르고 굿
# 0       2                      택배가 엉망이네용 저희집 밑에층에 말도없이 놔두고가고
# 1       5  아주좋아요 바지 정말 좋아서2개 더 구매했어요 이가격에 대박입니다. 바느질이 조금 ...
# 2       2  선물용으로 빨리 받아서 전달했어야 하는 상품이었는데 머그컵만 와서 당황했습니다. 전...
# 3       5                  민트색상 예뻐요. 옆 손잡이는 거는 용도로도 사용되네요 ㅎㅎ
# 4       2  비추합니다 계란 뒤집을 때 완전 불편해요 ㅠㅠ 코팅도 묻어나고 보기엔 예쁘고 실용적...
# ...    ..                                                ...
# 199994  2                                    장마라그런가!!! 달지않아요
# 199995  5  다이슨 케이스 구매했어요 다이슨 슈퍼소닉 드라이기 케이스 구매했어요가격 괜찮고 배송...
# 199996  5                    로드샾에서 사는것보다 세배 저렴하네요 ㅜㅜ 자주이용할께요
# 199997  5                                      넘이쁘고 쎄련되보이네요~
# 199998  5   아직 사용해보지도않았고 다른 제품을 써본적이없어서 잘 모르겠지만 ㅎㅎ 배송은 빨랐습니다
#
# [199999 rows x 2 columns]

# %%
df.columns = ["ratings", "comment"]
df
# Out:
#         ratings                                            comment
# 0             2                      택배가 엉망이네용 저희집 밑에층에 말도없이 놔두고가고
# 1             5  아주좋아요 바지 정말 좋아서2개 더 구매했어요 이가격에 대박입니다. 바느질이 조금 ...
# 2             2  선물용으로 빨리 받아서 전달했어야 하는 상품이었는데 머그컵만 와서 당황했습니다. 전...
# 3             5                  민트색상 예뻐요. 옆 손잡이는 거는 용도로도 사용되네요 ㅎㅎ
# 4             2  비추합니다 계란 뒤집을 때 완전 불편해요 ㅠㅠ 코팅도 묻어나고 보기엔 예쁘고 실용적...
# ...         ...                                                ...
# 199994        2                                    장마라그런가!!! 달지않아요
# 199995        5  다이슨 케이스 구매했어요 다이슨 슈퍼소닉 드라이기 케이스 구매했어요가격 괜찮고 배송...
# 199996        5                    로드샾에서 사는것보다 세배 저렴하네요 ㅜㅜ 자주이용할께요
# 199997        5                                      넘이쁘고 쎄련되보이네요~
# 199998        5   아직 사용해보지도않았고 다른 제품을 써본적이없어서 잘 모르겠지만 ㅎㅎ 배송은 빨랐습니다
#
# [199999 rows x 2 columns]

# %%
# %pip install PyKomoran #Komoran 설치

from PyKomoran import *
import re
komoran= Komoran(DEFAULT_MODEL['LIGHT'])
n_= []

for i in range(len(sunstic)):
  nouns = komoran.get_morphes_by_tags(sunstic.iloc[i]['review'], tag_list=['NNP', 'NNG','VA'])
  n_.append(' '.join(nouns))
sunstic['nouns'] = n_
sunstic = sunstic[sunstic['nouns']!='']
# Out:
# Collecting PyKomoran
#   Downloading PyKomoran-0.1.6.post1-py3-none-any.whl.metadata (4.9 kB)
# Collecting py4j==0.10.9.2 (from PyKomoran)
#   Downloading py4j-0.10.9.2-py2.py3-none-any.whl.metadata (1.3 kB)
# Downloading PyKomoran-0.1.6.post1-py3-none-any.whl (6.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 40.0 MB/s eta 0:00:0000:0100:01
# Downloading py4j-0.10.9.2-py2.py3-none-any.whl (198 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 198.8/198.8 kB 21.9 MB/s eta 0:00:00
# Installing collected packages: py4j, PyKomoran
# Successfully installed PyKomoran-0.1.6.post1 py4j-0.10.9.2
# Note: you may need to restart the kernel to use updated packages.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 8
#       5 komoran= Komoran(DEFAULT_MODEL['LIGHT'])
#       6 n_= []
# ----> 8 for i in range(len(sunstic)):
#       9   nouns = komoran.get_morphes_by_tags(sunstic.iloc[i]['review'], tag_list=['NNP', 'NNG','VA'])
#      10   n_.append(' '.join(nouns))
#
# NameError: name 'sunstic' is not defined

# %%
def lemmatize(sentence):
    morphtags = komoran.pos(sentence)
    words = []
    for m, t in enumerate(morphtags) :
      k = t.get_pos()
      if k=='NNP' or k=='NNG' :
        words.append(t.get_morph())
      elif k=='VA' or k=='VV' :
        words.append(t.get_morph()+'다')
    return words

w_ = []
for i in range(len(sunstic)) :
  words = lemmatize(sunstic.iloc[i]['review'])
  w_.append(' '.join(words))
sunstic['words'] = w_  
sunstic = sunstic[sunstic['words']!='']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 13
#      10     return words
#      12 w_ = []
# ---> 13 for i in range(len(sunstic)) :
#      14   words = lemmatize(sunstic.iloc[i]['review'])
#      15   w_.append(' '.join(words))
#
# NameError: name 'sunstic' is not defined
